# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\T L S\\Desktop\\SoftSinc\\Week 1\\train_and_test2.csv")

# %%
df.drop_duplicates(inplace=True)
df.dropna(subset=['Age', 'Pclass'], inplace=True)
df['Age'] = df['Age'].fillna(df['Age'].median()) 
df['Fare'] = df['Fare'].fillna(df['Fare'].median())
df.reset_index(drop=True, inplace=True)

# %%
print("\n Average survival rate by gender:")
print(df.groupby('Sex')['Survived'].mean())

print("\n Average age by passenger class:")
print(df.groupby('Pclass')['Age'].mean())

print("\n Survival rate by class:")
print(df.groupby('Pclass')['Survived'].mean())

print("\n Number of children (under 16) who survived:")
children_survived = df[(df['Age'] < 16) & (df['Survived'] == 1)]
print(len(children_survived))

print("\n Correlation matrix of numerical features:")
print(df.corr(numeric_only=True))
# Out:
#  Average survival rate by gender:
# Sex
# Female    0.497845
# Male      0.129300
# Name: Survived, dtype: float64
#
#  Average age by passenger class:
# Pclass
# 0.0    31.401556
# 1.0    28.256098
# 2.0    28.934081
# Name: Age, dtype: float64
#
#  Survival rate by class:
# Pclass
# 0.0    0.344444
# 1.0    0.243902
# 2.0    0.237418
# Name: Survived, dtype: float64
#
#  Number of children (under 16) who survived:
# 49
#
#  Correlation matrix of numerical features:
#              Passengerid       Age      Fare    Pclass  Survived
# Passengerid     1.000000  0.036305  0.031945 -0.051518 -0.331125
# Age             0.036305  1.000000  0.178139 -0.069386 -0.055863
# Fare            0.031945  0.178139  1.000000 -0.239212  0.171942
# Pclass         -0.051518 -0.069386 -0.239212  1.000000 -0.093225
# Survived       -0.331125 -0.055863  0.171942 -0.093225  1.000000

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(6, 4))
sns.barplot(data=df, x='Sex', y='Survived')
plt.title("Survival Rate by Gender")
plt.show()

plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True)
plt.title("Age Distribution by Survival")
plt.show()

plt.figure(figsize=(6, 4))
sns.barplot(data=df, x='Pclass', y='Survived')
plt.title("Survival Rate by Passenger Class")
plt.show()
